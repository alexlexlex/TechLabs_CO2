# %% [markdown]
# <a href="https://colab.research.google.com/github/alexlexlex/TechLabs_CO2/blob/main/S3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/gdrive')
df = pd.read_excel('/content/gdrive/MyDrive/Thesis_s3/s3_b.xlsx')
df.head()
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#    Refinitv_Screen     RIC Company_Common_Name  Organization_PermID  Year  \
# 0  INT NON US 4879  1U1.DE              1&1 AG           4295869472    -4
# 1  INT NON US 4879  1U1.DE              1&1 AG           4295869472     0
# 2  INT NON US 4879  1U1.DE              1&1 AG           4295869472    -1
# 3  INT NON US 4879  1U1.DE              1&1 AG           4295869472    -2
# 4  INT NON US 4879  1U1.DE              1&1 AG           4295869472    -3
#
#            ISIN CUSIP_extended  \
# 0  DE0005545503      D5934B101
# 1  DE0005545503      D5934B101
# 2  DE0005545503      D5934B101
# 3  DE0005545503      D5934B101
# 4  DE0005545503      D5934B101
#
#                                 Business_Description  \
# 0  1&1 Drillisch AG, formerly Drillisch AG, is a ...
# 1  1&1 Drillisch AG, formerly Drillisch AG, is a ...
# 2  1&1 Drillisch AG, formerly Drillisch AG, is a ...
# 3  1&1 Drillisch AG, formerly Drillisch AG, is a ...
# 4  1&1 Drillisch AG, formerly Drillisch AG, is a ...
#
#                     TRBC_Activity_Name                    TRBC_Industry_Name  \
# 0  Wireless Telecoms Service Providers  Wireless Telecommunications Services
# 1  Wireless Telecoms Service Providers  Wireless Telecommunications Services
# 2  Wireless Telecoms Service Providers  Wireless Telecommunications Services
# 3  Wireless Telecoms Service Providers  Wireless Telecommunications Services
# 4  Wireless Telecoms Service Providers  Wireless Telecommunications Services
#
#    ... Upstream_scope_3_emissions_Leased_Assets  \
# 0  ...                                      NaN
# 1  ...                                      NaN
# 2  ...                                      NaN
# 3  ...                                      NaN
# 4  ...                                      NaN
#
#   Downstream_scope_3_emissions_Transportation_and_Distribution  \
# 0                                                NaN
# 1                                            1422.39
# 2                                            1695.24
# 3                                            1904.02
# 4                                                NaN
#
#   Downstream_scope_3_emissions_Processing_of_Sold_Products  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Downstream_scope_3_emissions_Use_of_Sold_Products  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Downstream_scope_3_emissions_End_of_life_Treatment_of_Sold_Products  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Downstream_scope_3_emissions_Leased_Assets  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    Downstream_scope_3_emissions_Franchises  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    Downstream_scope_3_emissions_Investments  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Downstream_scope_3_emissions_Other Upstream_scope_3_emissions_Other
# 0                                NaN                              NaN
# 1                                NaN                              NaN
# 2                                NaN                              NaN
# 3                                NaN                              NaN
# 4                                NaN                              NaN
#
# [5 rows x 121 columns]
